# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from PIL import Image

# %%
im = Image.open('/Users/pedro/Dropbox/foto-pedro-web.png')

# %%
matriz_puntos=im.load()

# %%
for i in range(10,30): 
    for j in range (10,20):
        print(matriz_puntos[i,j])
# Out:
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# (255, 255, 255, 0)
# ...
