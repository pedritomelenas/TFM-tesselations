# %%
from tesselation import *

# %%
im = Image.open('RAIMUNDO.jpg')

# %%
t=Teselaciones(im)

# %% [markdown]
# All necessary information about groups is contained in the report.

# %% [markdown]
# Call Auxiliar functions, example t.mini()

# %%
t.mini()
# Out:
# <PIL.Image._ImageCrop image mode=RGB size=135x135 at 0x1065BB208>

# %%
t.SimVertical()
# Out:
# <PIL.Image.Image image mode=RGB size=270x135 at 0x1065BBA90>

# %%
t.SimHorizontal()
# Out:
# <PIL.Image.Image image mode=RGB size=135x270 at 0x1065BBA58>

# %%
t.SimHoDesliz()
# Out:
# <PIL.Image.Image image mode=RGB size=270x270 at 0x1065BBC50>

# %%
t.SimVeDesliz()
# Out:
# <PIL.Image.Image image mode=RGB size=270x270 at 0x1065CD978>

# %% [markdown]
# Rotations are include in pillow module

# %%
im.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=135x150 at 0x1065CDA58>

# %% [markdown]
# Frieze groups call is Teselaciones(image).Fgroup(Range)

# %%
t.F1(10)
# Out:
# <PIL.Image.Image image mode=RGB size=1350x135 at 0x1065CDBA8>

# %%
t.F11(10)
# Out:
# <PIL.Image.Image image mode=RGB size=1350x270 at 0x1065CDB70>

# %%
t.F12(7)
# Out:
# <PIL.Image.Image image mode=RGB size=1890x135 at 0x1065CDC50>

# %%
t.F13(5)
# Out:
# <PIL.Image.Image image mode=RGB size=1350x270 at 0x1065CDEF0>

# %%
t.F2(7)
# Out:
# <PIL.Image.Image image mode=RGBA size=1890x116 at 0x1065D2080>

# %%
t.F21(7)
# Out:
# <PIL.Image.Image image mode=RGB size=1890x270 at 0x1065D2198>

# %%
t.F22(7)
# Out:
# <PIL.Image.Image image mode=RGB size=1890x270 at 0x1065D2320>

# %% [markdown]
# Cristalographic groups call: Teselaciones(image).Fgroup(Range)

# %%
t.p1(4)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D2208>

# %%
t.p2(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D24A8>

# %%
t.pm(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D25F8>

# %%
t.pg(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D2748>

# %%
t.pmm(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D27F0>

# %%
t.cm(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D29E8>

# %%
t.pgg(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D29B0>

# %%
t.pmg(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D2908>

# %%
t.p4(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D2CF8>

# %%
t.triangulo()
# Out:
# <PIL.Image.Image image mode=RGBA size=150x135 at 0x1065D2C50>

# %%
t.cmm(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x1065D2E80>

# %%
t.divi1()
# Out:
# <PIL.Image.Image image mode=RGBA size=135x135 at 0x1065D2D68>

# %%
t.p4mm(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x106F10198>

# %%
t.divi2()
# Out:
# <PIL.Image.Image image mode=RGBA size=135x135 at 0x1065D2EF0>

# %%
t.p4g(2)
# Out:
# <PIL.Image.Image image mode=RGB size=540x540 at 0x106F10278>

# %%
t.equilatero()
# Out:
# <PIL.Image.Image image mode=RGBA size=135x116 at 0x106F102E8>

# %%
t.p3(3)
# Out:
# <PIL.Image.Image image mode=RGBA size=1215x1044 at 0x106F10438>

# %%
t.p31m(2)
# Out:
# <PIL.Image.Image image mode=RGBA size=810x696 at 0x106F10668>

# %%
t.fundam()
# Out:
# <PIL.Image.Image image mode=RGBA size=135x116 at 0x106F101D0>

# %%
t.fundam2()
# Out:
# <PIL.Image._ImageCrop image mode=RGBA size=135x116 at 0x106F104A8>

# %%
t.p3m1(2)
# Out:
# <PIL.Image.Image image mode=RGBA size=810x696 at 0x106F106A0>

# %%
t.p6(2)
# Out:
# <PIL.Image.Image image mode=RGBA size=810x696 at 0x106F105C0>

# %%
t.fundam3()
# Out:
# <PIL.Image.Image image mode=RGBA size=135x116 at 0x106F10AC8>

# %%
t.fundam4()
# Out:
# <PIL.Image.Image image mode=RGBA size=135x116 at 0x106F10D68>

# %%
t.p6m(2)
# Out:
# <PIL.Image.Image image mode=RGBA size=810x696 at 0x106F108D0>
