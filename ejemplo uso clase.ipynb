# %%
from tesselation import *

# %%
imagen = Image.open("Ejemplos/salamanquesa.jpeg")

# %%
t=Teselaciones(imagen)

# %%
t.mini()
# Out:
# <PIL.Image._ImageCrop image mode=RGB size=200x200 at 0x105F819B0>

# %%
t.SimVertical()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x105F81A90>

# %%
t.p1(2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x105F81CC0>
